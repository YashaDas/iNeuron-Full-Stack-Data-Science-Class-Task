# %% [markdown]
# ### TASK 2 - Superstore_USA

# %% [markdown]
# #### 1. Load this data in sql and in pandas with a relation in sql

# %%
# mysql
import mysql.connector as conn

mydb = conn.connect(host = "localhost", user = "root", passwd = "password")
cursor = mydb.cursor()
cursor.execute("create database Superstore_USA")
cursor.execute("show databases")
for i in cursor.fetchall():
    print(i)

# %%
# pandas

import pandas as pd

# %%
# reading the 'Superstore_USA' dataset in pandas

orders = pd.read_excel(r'C:\Users\Computers\Downloads\Superstore_USA.xlsx')

# %%
orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# reading the second sheet in the 'Superstore_USA' dataset called Returns

returns = pd.read_excel(r'C:\Users\Computers\Downloads\Superstore_USA.xlsx',sheet_name = "Returns")

# %%
returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
# reading the third sheet in the 'Superstore_USA' dataset called Users

users = pd.read_excel(r'C:\Users\Computers\Downloads\Superstore_USA.xlsx',sheet_name = "Users")

# %%
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# #### 2. While loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table.

# %%
# To bulk load data in MySQ, we need to follow the process which is given below:

# First to load excel file directly into database, we have to convert it into CSV file format. 

# Then do as follows:

# STEP 1 : Right click on Tables  
# STEP 2 : Select "Table Data Import Wizard"
# STEP 3 : Select the dataset which we have to load (here, it is 'SuperStore_USA.csv') and press next.
# STEP 4 : Select create new table and give the table name and press next.
# STEP 5 : Select the required conditions and press next. The data is loaded Successfully.

# %% [markdown]
# #### 3. Find out how much return that we have recived and with a product id.

# %%
orders_returns = pd.merge(orders, returns)

# %%
d = pd.DataFrame(orders_returns)

# %%
orders_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
d[(d['Status']=='Returned')]['Order ID'] 
# Using 'Order ID' since there is no column named as 'Product ID' available in the given dataset
# Out:
# 0      9895
# 1     13959
# 2     13959
# 3     36038
# 4     39490
#       ...
# 93     7107
# 94     7107
# 95    42823
# 96    13638
# 97    47109
# Name: Order ID, Length: 98, dtype: int64

# %%
len(d[(d['Status']=='Returned')]['Order ID'])
# Out:
# 98

# %% [markdown]
# #### 4. Try to join order and return data both in sql and pandas.

# %%
# joining order and return data in pandas

pd.merge(orders, returns)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
# joining order and return data in sql

select * from orders INNER JOIN returns ON orders.Order ID = returns.order ID;

# %% [markdown]
# #### 5. Try to find out how many unique customer that we have.

# %%
orders['Customer ID'].unique()
# Out:
# array([   2,    3,    5, ..., 3400, 3402, 3403], dtype=int64)

# %%
len(orders['Customer ID'].unique())
# Out:
# 2703

# %% [markdown]
# #### 6. Try to find out in how many regions we are selling a product and who is a manager for a respective region.

# %%
users['Region'].unique()
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
len(users['Region'].unique())
# Out:
# 4

# %%
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# #### 7. Find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset.

# %%
orders['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
len(orders['Ship Mode'].unique())
# Out:
# 3

# %%
orders['Ship Mode'].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
sm
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
sm.sum()
# Out:
# 9426

# %%
sm.sum()/100
# Out:
# 94.26

# %% [markdown]
# #### 8. Create a new coulmn and try to find our a diffrence between order date and shipment date.

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
orders['difference_date'] = orders['Order Date'] - orders['Ship Date']

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
orders['difference_date']
# Out:
# 0      -2 days
# 1      -1 days
# 2      -1 days
# 3      -1 days
# 4       0 days
#          ...
# 9421   -1 days
# 9422    0 days
# 9423   -2 days
# 9424   -3 days
# 9425   -2 days
# Name: difference_date, Length: 9426, dtype: timedelta64[ns]

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %% [markdown]
# #### 9. Based on question number 8 find out for which order id we have shipment duration more than 10 days.

# %%
shipment_duration = orders['difference_date']

# %%
shipment_duration
# Out:
# 0      -2 days
# 1      -1 days
# 2      -1 days
# 3      -1 days
# 4       0 days
#          ...
# 9421   -1 days
# 9422    0 days
# 9423   -2 days
# 9424   -3 days
# 9425   -2 days
# Name: difference_date, Length: 9426, dtype: timedelta64[ns]

# %%
type(shipment_duration)
# Out:
# pandas.core.series.Series

# %%
orders[(orders['difference_date'].dt.components['days']>10)]

# %%
orders[(orders['difference_date'].dt.components['days']>10)]['OrderID']

# %% [markdown]
# #### 10. Try to find out a list of a returned order which shipment duration was more then 15 days and find out that region manager as well.

# %%
orders_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
orders_returns1 = pd.merge(orders,returns, how = 'inner')

# %%
orders_returns1.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date',
#        'Status'],
#       dtype='object')

# %%
orders_returns1['Status']
# Out:
# 0     Returned
# 1     Returned
# 2     Returned
# 3     Returned
# 4     Returned
#         ...
# 93    Returned
# 94    Returned
# 95    Returned
# 96    Returned
# 97    Returned
# Name: Status, Length: 98, dtype: object

# %%
orders_returns1[(orders_returns1['difference_date'].dt.components['days']>15)]

# %%
orders_users = pd.merge(orders, users, how = 'inner')

# %%
orders_users.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date',
#        'Manager'],
#       dtype='object')

# %%
orders_users['Manager'].unique()
# Out:
# array(['Chris', 'William', 'Erin', 'Sam'], dtype=object)

# %%
orders_users[(orders_users['difference_date'].dt.components['days']>15)]['Manager']

# %% [markdown]
# #### 11. Gorup by region and find out which region is more profitable.

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
orders.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Region                           object
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# Sales                           float64
# ...

# %%
orders.groupby(['Region'])['Profit'].aggregate('count')
# Out:
# Region
# Central    2899
# East       2289
# South      1954
# West       2284
# Name: Profit, dtype: int64

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index()
# Out:
#     Region  Profit
# 0  Central    2899
# 1     East    2289
# 2    South    1954
# 3     West    2284

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit")
# Out:
#     Region  Profit
# 2    South    1954
# 3     West    2284
# 1     East    2289
# 0  Central    2899

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = False)
# Out:
#     Region  Profit
# 0  Central    2899
# 1     East    2289
# 3     West    2284
# 2    South    1954

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = False).iloc[[0]]
# Out:
#     Region  Profit
# 0  Central    2899

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = False).iloc[0]
# Out:
# Region    Central
# Profit       2899
# Name: 0, dtype: object

# %% [markdown]
# #### 12. Try to find out overalll in which country we are giving more didscount.

# %%
orders.groupby(['Region'])['Discount'].aggregate('count')
# Out:
# Region
# Central    2899
# East       2289
# South      1954
# West       2284
# Name: Discount, dtype: int64

# %%
orders.groupby(['Region'])['Discount'].aggregate('count').reset_index()
# Out:
#     Region  Discount
# 0  Central      2899
# 1     East      2289
# 2    South      1954
# 3     West      2284

# %%
orders.groupby(['Region'])['Discount'].aggregate('count').reset_index().sort_values("Discount",ascending = False).iloc[[0]]
# Out:
#     Region  Discount
# 0  Central      2899

# %%
orders.groupby(['Region'])['Discount'].aggregate('count').reset_index().sort_values("Discount",ascending = False).iloc[0]
# Out:
# Region      Central
# Discount       2899
# Name: 0, dtype: object

# %%
orders['Discount'].unique()
# Out:
# array([0.01, 0.03, 0.  , 0.09, 0.08, 0.02, 0.07, 0.1 , 0.05, 0.06, 0.04,
#        0.11, 0.17, 0.16, 0.25, 0.21])

# %%
[orders[orders['Discount']>0.21]['Region']]
# Out:
# [8649    Central
#  Name: Region, dtype: object]

# %% [markdown]
# #### 13. Give me a list of unique postal code.

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
postal_code_unique = orders['Postal Code'].unique()

# %%
list(postal_code_unique)
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %% [markdown]
# #### 14. Which customer segement is more profitalble find it out.

# %%
orders.groupby(['Customer Segment'])['Profit'].aggregate('count')
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
orders.groupby(['Customer Segment'])['Profit'].aggregate('count').reset_index()
# Out:
#   Customer Segment  Profit
# 0         Consumer    1894
# 1        Corporate    3375
# 2      Home Office    2316
# 3   Small Business    1841

# %%
orders.groupby(['Customer Segment'])['Profit'].aggregate('count').reset_index().sort_values('Profit', ascending = False)
# Out:
#   Customer Segment  Profit
# 1        Corporate    3375
# 2      Home Office    2316
# 0         Consumer    1894
# 3   Small Business    1841

# %%
orders.groupby(['Customer Segment'])['Profit'].aggregate('count').reset_index().sort_values('Profit', ascending = False).iloc[[0]]
# Out:
#   Customer Segment  Profit
# 1        Corporate    3375

# %% [markdown]
# #### 15. Try to find out the 10th most loss making product catagory.

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
orders[orders['Profit']<0]['Product Category']
# Out:
# 2       Office Supplies
# 3       Office Supplies
# 8       Office Supplies
# 10      Office Supplies
# 14            Furniture
#              ...
# 9415         Technology
# 9418    Office Supplies
# 9420          Furniture
# 9422    Office Supplies
# 9423          Furniture
# Name: Product Category, Length: 4558, dtype: object

# %%
orders[orders['Profit']<0]['Product Category'].iloc[9]
# Out:
# 'Office Supplies'

# %% [markdown]
# #### 16. Try to find out 10 top  product with highest margins.

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
orders.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object

# %%
orders.sort_values(['Product Base Margin'], ascending = False)['Product Name'].head(10)
# Out:
# 9145                                          Accessory27
# 4756                                           Accessory4
# 7607                                          Accessory27
# 5672                                           Accessory4
# 4168                    Sterling Rubber Bands by Alliance
# 807                                           Accessory27
# 816                                           Accessory27
# 3994    Office Impressions Heavy Duty Welded Shelving ...
# 2138                    Sterling Rubber Bands by Alliance
# 7202    Office Impressions Heavy Duty Welded Shelving ...
# Name: Product Name, dtype: object
